# %%
import pandas as pd
from datetime import datetime

# 1. Baca data tugas
df = pd.read_csv('tasks.csv')
df
# Out:
#            name  difficulty  weight    deadline
# 0         Essay           4       8   12/5/2025
# 1  Presentation           3       6   12/1/2025
# 2      Reminder           1       3  12/20/2025

# %%
# 2. Ubah deadline jadi datetime
# format '%m/%d/%Y' karena bentuknya (MM/DD/YYYY)
df['deadline'] = pd.to_datetime(df['deadline'], format='%m/%d/%Y')

# 3. Hitung berapa hari lagi sampai deadline
today = datetime.now()
df['days_until_deadline'] = (df['deadline'] - today).dt.days.clip(lower=0)

df
# Out:
#            name  difficulty  weight   deadline  days_until_deadline
# 0         Essay           4       8 2025-12-05                    4
# 1  Presentation           3       6 2025-12-01                    0
# 2      Reminder           1       3 2025-12-20                   19

# %%
# 4. Tambahkan target(label) yang ingin dipelajari model
priority_label_map = {
    'Presentation': 100,
    'Essay': 80,
    'Reminder': 40
}

df['priority_label'] = df['name'].map(priority_label_map)
df
# Out:
#            name  difficulty  weight   deadline  days_until_deadline  \
# 0         Essay           4       8 2025-12-05                    4
# 1  Presentation           3       6 2025-12-01                    0
# 2      Reminder           1       3 2025-12-20                   19
#
#    priority_label
# 0              80
# 1             100
# 2              40

# %%
# 5. Masukkan Library yang diperlukan
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import joblib

# %%
# Latih model dengan split
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.33, random_state=42
)

tmp_model = DecisionTreeRegressor(random_state=42)
tmp_model.fit(X_train, y_train)

y_pred = tmp_model.predict(X_val)
print("MAE:", mean_absolute_error(y_val, y_pred))

# Model final dilatih dengan semua data 
model = DecisionTreeRegressor(random_state=42)
model.fit(X, y)

joblib.dump(model, 'task_ranker_model.pkl')
# Out:
# MAE: 20.0
# ['task_ranker_model.pkl']

# %%
tasks = [
    {"name": "Presentation", "difficulty": 7, "weight": 9, "deadline": "12/03/2025"},
    {"name": "Essay", "difficulty": 5, "weight": 6, "deadline": "12/10/2025"},
    {"name": "Essay", "difficulty": 4, "weight": 5, "deadline": "12/08/2025"},
    {"name": "Presentation", "difficulty": 8, "weight": 10, "deadline": "12/12/2025"},
    {"name": "Essay", "difficulty": 6, "weight": 7, "deadline": "12/04/2025"},
    {"name": "Presentation", "difficulty": 9, "weight": 9, "deadline": "12/20/2025"},
    {"name": "Presentation", "difficulty": 6, "weight": 8, "deadline": "12/05/2025"},
    {"name": "Presentation", "difficulty": 7, "weight": 7, "deadline": "12/05/2025"},
    {"name": "Presentation", "difficulty": 10, "weight": 10, "deadline": "12/22/2025"},
    {"name": "Essay", "difficulty": 7, "weight": 8, "deadline": "12/06/2025"},
    {"name": "Reminder", "difficulty": 2, "weight": 5, "deadline": "12/11/2025"},
    {"name": "Presentation", "difficulty": 9, "weight": 7, "deadline": "12/17/2025"},
    {"name": "Essay", "difficulty": 5, "weight": 6, "deadline": "12/19/2025"},
    {"name": "Presentation", "difficulty": 8, "weight": 8, "deadline": "12/16/2025"},
    {"name": "Essay", "difficulty": 3, "weight": 5, "deadline": "12/21/2025"}
]
df = pd.DataFrame(tasks)
df
# Out:
#             name  difficulty  weight    deadline
# 0   Presentation           7       9  12/03/2025
# 1          Essay           5       6  12/10/2025
# 2          Essay           4       5  12/08/2025
# 3   Presentation           8      10  12/12/2025
# 4          Essay           6       7  12/04/2025
# 5   Presentation           9       9  12/20/2025
# 6   Presentation           6       8  12/05/2025
# 7   Presentation           7       7  12/05/2025
# 8   Presentation          10      10  12/22/2025
# 9          Essay           7       8  12/06/2025
# 10      Reminder           2       5  12/11/2025
# 11  Presentation           9       7  12/17/2025
# 12         Essay           5       6  12/19/2025
# 13  Presentation           8       8  12/16/2025
# 14         Essay           3       5  12/21/2025

# %%
df['deadline'] = pd.to_datetime(df['deadline'], format='%m/%d/%Y')

today = datetime.now()
df['days_until_deadline'] = (df['deadline'] - today).dt.days.clip(lower=0)

df
# Out:
#             name  difficulty  weight   deadline  days_until_deadline
# 0   Presentation           7       9 2025-12-03                    0
# 1          Essay           5       6 2025-12-10                    7
# 2          Essay           4       5 2025-12-08                    5
# 3   Presentation           8      10 2025-12-12                    9
# 4          Essay           6       7 2025-12-04                    1
# 5   Presentation           9       9 2025-12-20                   17
# 6   Presentation           6       8 2025-12-05                    2
# 7   Presentation           7       7 2025-12-05                    2
# 8   Presentation          10      10 2025-12-22                   19
# 9          Essay           7       8 2025-12-06                    3
# 10      Reminder           2       5 2025-12-11                    8
# 11  Presentation           9       7 2025-12-17                   14
# 12         Essay           5       6 2025-12-19                   16
# ...

# %%
import joblib

model = joblib.load('task_ranker_model.pkl')

# %%
x_new = df[['difficulty','weight','days_until_deadline']]

df['priority _score'] = model.predict(x_new)
df
# Out:
#             name  difficulty  weight   deadline  days_until_deadline  \
# 0   Presentation           7       9 2025-12-03                    0
# 1          Essay           5       6 2025-12-10                    7
# 2          Essay           4       5 2025-12-08                    5
# 3   Presentation           8      10 2025-12-12                    9
# 4          Essay           6       7 2025-12-04                    1
# 5   Presentation           9       9 2025-12-20                   17
# 6   Presentation           6       8 2025-12-05                    2
# 7   Presentation           7       7 2025-12-05                    2
# 8   Presentation          10      10 2025-12-22                   19
# 9          Essay           7       8 2025-12-06                    3
# 10      Reminder           2       5 2025-12-11                    8
# 11  Presentation           9       7 2025-12-17                   14
# 12         Essay           5       6 2025-12-19                   16
# ...

# %%
df_sorted = df.sort_values(
    by=['priority _score','days_until_deadline'],
    ascending=[False, True]
)

df_sorted
# Out:
#             name  difficulty  weight   deadline  days_until_deadline  \
# 0   Presentation           7       9 2025-12-03                    0
# 4          Essay           6       7 2025-12-04                    1
# 6   Presentation           6       8 2025-12-05                    2
# 7   Presentation           7       7 2025-12-05                    2
# 9          Essay           7       8 2025-12-06                    3
# 2          Essay           4       5 2025-12-08                    5
# 1          Essay           5       6 2025-12-10                    7
# 10      Reminder           2       5 2025-12-11                    8
# 3   Presentation           8      10 2025-12-12                    9
# 13  Presentation           8       8 2025-12-16                   13
# 11  Presentation           9       7 2025-12-17                   14
# 12         Essay           5       6 2025-12-19                   16
# 5   Presentation           9       9 2025-12-20                   17
# ...
